# %% [markdown]
# # quick revenue look
#
# Need a chart for the meeting.

# %%
import pandas as pd
DATA='demo/notebook-rescue/data/monthly_revenue.csv'
df = pd.read_csv(DATA)
df.head()

# %%
# hidden state: changed this after looking at the data
focus_segment = 'enterprise'
df = df[df.segment == focus_segment]
df.groupby('month').revenue.sum()

# %%
# scratch cell from a failed attempt
tmp = df[df.revenue > 1000]
tmp
